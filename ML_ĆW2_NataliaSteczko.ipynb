# %% [markdown]
# Zadanie 1 </p>
# Zdefiniuj klasę implementującą regresję liniową z regularyzacją L1/L2 dla dowolnej liczby zmiennych.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
class LassoRegression() :
      
    def __init__( self, learning_rate, iterations, l1_penality ) :
          
        self.learning_rate = learning_rate
          
        self.iterations = iterations
          
        self.l1_penality = l1_penality
          
    #funkcja modelu treningowego
              
    def fit( self, X, Y ) :
          
        #no_of_training_examples, no_of_features
          
        self.m, self.n = X.shape
          
        #wagi
          
        self.W = np.zeros( self.n )
          
        self.b = 0
          
        self.X = X
          
        self.Y = Y
          
        #gradient 
                  
        for i in range( self.iterations ) :
              
            self.update_weights()
              
        return self
      
    #update weights
      
    def update_weights( self ) :
             
        Y_pred = self.predict( self.X )
          
        #oszacowanie gradientu  
          
        dW = np.zeros( self.n )
          
        for j in range( self.n ) :
              
            if self.W[j] > 0 :
                  
                dW[j] = ( - ( 2 * ( self.X[:, j] ).dot( self.Y - Y_pred ) ) 
                           
                         + self.l1_penality ) / self.m
          
            else :
                  
                dW[j] = ( - ( 2 * ( self.X[:, j] ).dot( self.Y - Y_pred ) ) 
                           
                         - self.l1_penality ) / self.m
  
       
        db = - 2 * np.sum( self.Y - Y_pred ) / self.m 
          
        #update weights
      
        self.W = self.W - self.learning_rate * dW
      
        self.b = self.b - self.learning_rate * db
          
        return self
      
    #funkcja h(x) 
      
    def predict( self, X ) :
      
        return X.dot( self.W ) + self.b

# %%
X = np.linspace((1,2,3,4),(11, 22, 33, 10),300)
# Out:
# array([[ 1.        ,  2.        ,  3.        ],
#        [ 1.03344482,  2.06688963,  3.10033445],
#        [ 1.06688963,  2.13377926,  3.2006689 ],
#        [ 1.10033445,  2.2006689 ,  3.30100334],
#        [ 1.13377926,  2.26755853,  3.40133779],
#        [ 1.16722408,  2.33444816,  3.50167224],
#        [ 1.2006689 ,  2.40133779,  3.60200669],
#        [ 1.23411371,  2.46822742,  3.70234114],
#        [ 1.26755853,  2.53511706,  3.80267559],
#        [ 1.30100334,  2.60200669,  3.90301003],
#        [ 1.33444816,  2.66889632,  4.00334448],
#        [ 1.36789298,  2.73578595,  4.10367893],
#        [ 1.40133779,  2.80267559,  4.20401338],
#        [ 1.43478261,  2.86956522,  4.30434783],
#        [ 1.46822742,  2.93645485,  4.40468227],
#        [ 1.50167224,  3.00334448,  4.50501672],
#        [ 1.53511706,  3.07023411,  4.60535117],
#        [ 1.56856187,  3.13712375,  4.70568562],
#        [ 1.60200669,  3.20401338,  4.80602007],
#        [ 1.63545151,  3.27090301,  4.90635452],
# ...

# %%
#przykładowe dane
c2 = 0.01
c1 = 1.4
c0 = 3.567

grid = np.linspace((1,2,3,4),(10,20,30,40),300)
X = grid[:, :-1]
y = grid[:, -1]
print(x_in.shape)
print(y.shape)
# Out:
# (300, 4)
# (300,)

# %%
#trenowanie za pomocą L2
x_train, x_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20)
print(x_train.shape)
lam = 0.1
ridge = LassoRegression(lam, 100, 500)
ridge.fit(x_train, y_train)
ridge.predict(x_test)
# Out:
# (240, 3)
# array([-1.03368696e+205, -9.61795328e+204, -1.24257780e+204,
#        -9.94146564e+204, -8.93498275e+204, -6.23904643e+204,
#        -3.14770613e+204, -5.16067191e+204, -4.98094282e+204,
#        -2.78824795e+204, -3.03986868e+204, -7.71282495e+204,
#        -1.56609016e+204, -2.24906069e+204, -7.92849986e+204,
#        -1.13433525e+205, -8.86309111e+204, -5.98742571e+204,
#        -3.11176031e+204, -7.67687913e+204, -1.45825271e+204,
#        -9.00687438e+204, -4.83715955e+204, -1.15590274e+205,
#        -9.29444092e+204, -4.04635157e+204, -5.26850936e+204,
#        -2.28500651e+204, -2.42878978e+204, -5.69985917e+204,
#        -1.38636107e+204, -3.68689339e+204, -3.72283921e+204,
#        -2.96797704e+204, -4.29797229e+204, -6.56255879e+204,
#        -5.52013008e+204, -1.88960252e+204, -9.90551982e+204,
#        -9.07876602e+204, -4.15418902e+204, -9.72579073e+204,
#        -8.07228313e+204, -9.68984491e+204, -6.95796278e+204,
# ...

# %%
class RidgeRegression() :
      
    def __init__( self, learning_rate, iterations, l2_penality ) :
          
        self.learning_rate = learning_rate        
        self.iterations = iterations        
        self.l2_penality = l2_penality
          
    #funkcja dla modelu treningowego            
    def fit( self, X, Y ) :
                 
        self.m, self.n = X.shape
        #wagi       
        self.W = np.zeros( self.n )
          
        self.b = 0        
        self.X = X        
        self.Y = Y
          
        #gradient
                  
        for i in range( self.iterations ) :            
            self.update_weights()            
        return self
    
     def update_weights( self ) :           
        Y_pred = self.predict( self.X )
          
        #obliczanie gradientu      
        dW = ( - ( 2 * ( self.X.T ).dot( self.Y - Y_pred ) ) +               
               ( 2 * self.l2_penality * self.W ) ) / self.m     
        db = - 2 * np.sum( self.Y - Y_pred ) / self.m 
          
        #aktualizacja   
        self.W = self.W - self.learning_rate * dW    
        self.b = self.b - self.learning_rate * db        
        return self
    
    #funkcja
    def predict( self, X ) :    
        return X.dot( self.W ) + self.b

# %%
#wersja 2
#instancja modelu i wywołanie metody fit
logreg = LogisticRegression().fit(X_train, y_train) #fit czyli self

#wywołanie metod fit i predict
logreg = LogisticRegression()
y_pred = logreg.fit(X_train, y_train).predict(X_test)

#w jednym wierszu obie
y_pred = LogisticRegression().fit(X_train, y_train).predict(X_test)
#w jednym wierszu wiele metod co utrudnia odczyt

# %% [markdown]
# Zadanie 2 </p>
#
# Wybierz dowolny zbiór danych lub wygeneruj syntetyczne dane. Zastosuj model regresji liniowej z regularyzacją L1. Na podstawie zbioru walidacyjnego wybierz optymalne parametry eta oraz alfa (rozważ chociaż 15-20 różnych kombinacji).

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
from sklearn.linear_model import LogisticRegression

# %%
   def train_test_val_split(data, target, test_size, val_size):
        val_size_in_regards_to_test_size = (len(target) * val_size)/(len(target) * test_size)
        X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=test_size, random_state=42)
        X_valid, X_test, y_valid, y_test = train_test_split(X_test, 
                                                            y_test, 
                                                            test_size=0.5, 
                                                            random_state=42
                                                           )
    
        return X_train, X_valid, X_test, y_train, y_valid, y_test

# %%
X_train, X_valid, X_test, y_train, y_valid, y_test = train_test_val_split(cancer.data, cancer.target, 0.4, 0.5)

# %%
X_train, X_test, y_train, y_test = train_test_split(
cancer.data, cancer.target, stratify=cancer.target, random_state=42)

#dla domyślnej wartości C=1
logreg = LogisticRegression().fit(X_train, y_train)
print("Wynik dla zestawu uczącego: {:.3f}".format(logreg.score(X_train, y_train)))
print("Wynik dla zestawu testowego: {:.3f}".format(logreg.score(X_test, y_test)))
# Out:
# Wynik dla zestawu uczącego: 0.955
# Wynik dla zestawu testowego: 0.958
# C:\Users\natal\miniconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
#dla C=100
logreg100 = LogisticRegression(C=100).fit(X_train, y_train)
print("Wynik dla zestawu uczącego: {:.3f}".format(logreg100.score(X_train, y_train)))
print("Wynik dla zestawu testowego: {:.3f}".format(logreg100.score(X_test, y_test)))
# Out:
# Wynik dla zestawu uczącego: 0.948
# Wynik dla zestawu testowego: 0.951
# C:\Users\natal\miniconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
#dla C=0.01
logreg001 = LogisticRegression(C=0.01).fit(X_train, y_train)
print("Wynik dla zestawu uczącego: {:.3f}".format(logreg001.score(X_train, y_train)))
print("Wynik dla zestawu testowego: {:.3f}".format(logreg001.score(X_test, y_test)))
# Out:
# Wynik dla zestawu uczącego: 0.934
# Wynik dla zestawu testowego: 0.930
# C:\Users\natal\miniconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %% [markdown]
# Zadanie 3 </p>
#
# Uzasadnij powyższe wartości prawdopodobieństw w oparciu o parametry modelu. </p>
#
# Ponieważ model LogisticRegression domyślnie stosuje regularyzację L2. Silniejsza regularyzacja zbliża wartości współczynników do zera, chociaż one nigdy nie będą równe 0. Parametry modelu w dwóch pierwszych przypadkach muszą mieć (dość) wysokie wartości C, dlatego dają współczynniki ujemne. Przy ostatniej wartości wartość C nie była zbyt wyoska, dlatego dała współczynnik dodatni. Z racji tego, że prawdopodobieństwo otrzymane na podstawie wartości w oparciu o parametry modelu znajduje się w przedziale <0,1> określa to, że wcześniejsze szacowania były dobre, przez co model jest dobry i dalsze przewidywania (prognozy) również będą dobre.

# %% [markdown]
# Zadanie 4 </p>
#
# Wyznacz powyższe prawdopodobieństwa ręcznie na podstawie parametrów modelu. </p> (rozwiązanie w Excel)

# %% [markdown]
# Zadanie 5 </p>
#
# Model przedstawiony na wykresie pokazuje co się stanie w przypadku overfittingu. Gdy model wygenerowany na danych testowych nie przewiduje prawidłowo to dochodzi to tego zjawiska.
# Zazwyczaj dzieje się tak w przypadku za dużej liczby danych i zbyt wysokiego szumu, wtedy model nie rozchodzi się poprawnie.
#
# Pobawiłam się efektami na tej stronie, aby uzyskać podobne wnioski. Zwłaszcza na tym ostanim rodzaju danych w w przypadku wysokiego szumu generowany wykres pokazuje podobne wyniki.
# playground.tensorflow.org
